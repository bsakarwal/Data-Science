# %%
import pandas as pd
import numpy as np
import inventorize3 as inv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %%html
# <style>
# .cm-comment {
#     color: white !important;
# }
# </style>
# Out:
# <style>
# .cm-comment {
#     color: white !important;
# }
# </style>

# %%
data=pd.read_csv('for_abc.csv')

# %%
data=data.drop('Unnamed: 0',axis=1)

# %%
data.head()
# Out:
#                            Description  total_sales  total_revenue
# 0    DOORMAT UNION JACK GUNS AND ROSES          167        1071.25
# 1             3 STRIPEY MICE FELTCRAFT          662        1241.10
# 2        4 PURPLE FLOCK DINNER CANDLES          324         495.16
# 3        50'S CHRISTMAS GIFT BAG LARGE         1885        2272.25
# 4                      ANIMAL STICKERS          385          80.85

# %%
data['Description']
# Out:
# 0         DOORMAT UNION JACK GUNS AND ROSES
# 1                  3 STRIPEY MICE FELTCRAFT
# 2             4 PURPLE FLOCK DINNER CANDLES
# 3             50'S CHRISTMAS GIFT BAG LARGE
# 4                           ANIMAL STICKERS
#                        ...
# 5278        ZINC T-LIGHT HOLDER STARS SMALL
# 5279         ZINC TOP  2 DOOR WOODEN SHELF
# 5280       ZINC WILLIE WINKIE  CANDLE STICK
# 5281            ZINC WIRE KITCHEN ORGANISER
# 5282       ZINC WIRE SWEETHEART LETTER TRAY
# Name: Description, Length: 5283, dtype: object

# %%
abc_analysis=inv.ABC(data[['Description','total_sales']])

# %%
abc_analysis
# Out:
#                              Description  total_sales    Percentage  \
# 5168   WORLD WAR 2 GLIDERS ASSTD DESIGNS       105185  9.990307e-03
# 5047  WHITE HANGING HEART T-LIGHT HOLDER        91757  8.714937e-03
# 3129         PAPER CRAFT , LITTLE BIRDIE        80995  7.692779e-03
# 292        ASSORTED COLOUR BIRD ORNAMENT        78234  7.430543e-03
# 2695      MEDIUM CERAMIC TOP STORAGE JAR        77916  7.400340e-03
# ...                                  ...          ...           ...
# 3451           PINK STRIPES SHOULDER BAG            1  9.497844e-08
# 4370     SILVER AND BLACK ORBIT NECKLACE            1  9.497844e-08
# 479       BLACK DIAMOND CLUSTER EARRINGS            1  9.497844e-08
# 4271     SET/2 SPOTTY + ROSE TEA TOWELS             1  9.497844e-08
# 4046     SET 12 COLOURING PENCILS DOILEY            1  9.497844e-08
#
#       comulative Category
# 5168    0.009990        A
# 5047    0.018705        A
# 3129    0.026398        A
# 292     0.033829        A
# 2695    0.041229        A
# ...          ...      ...
# 3451    1.000000        C
# 4370    1.000000        C
# 479     1.000000        C
# 4271    1.000000        C
# 4046    1.000000        C
#
# [5283 rows x 5 columns]

# %%
abc_analysis[['Category']].value_counts()
# Out:
# Category
# C           2881
# B           1245
# A           1157
# dtype: int64

# %%
sns.countplot(x='Category',data=abc_analysis)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
# Create the count plot
ax = sns.countplot(x='Category', data=abc_analysis)

# Add data labels on the count bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'),
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom')
plt.show()

# %%
#abc_analysis.plot(x='Category',y='total_sales',kind='bar')
sns.barplot(x='Category',y='total_sales',data=abc_analysis)
# Out:
# <Axes: xlabel='Category', ylabel='total_sales'>

# %%
help(inv.productmix)
# Out:
# Help on function productmix in module inventorize3:
#
# productmix(skus, sales, revenue)
#     [Identyfing ABC category based on the pareto rule for both demand and selling price,a mix of nine categories are produced.
#     Identyfing ABC category based on the pareto rule.A category is up to 80%. B category is up 95% and C category is up to 100%.
#      ]
#
#     Args:
#     SKUs ([array]): [charachter, a vector of SKU names.]
#     sales ([array]): [a vector of items sold per sku, should be the same number of rows as SKUs.]
#     revenue ([array]): [a vector of total revenue  per sku, should be the same number of rows as SKUs.]
#
#
#     Returns:
#     [pandas.DataFrame]: [a dataframe that contains ABC categories by sales and rvenue]
#     Examples:
#     [ productmix(SKUs= numpy.array(range(1,1001)),sales = ales= numpy.random.uniform(1,10000,1000),
#     revenue=numpy.random.uniform(1,80000,1000))]

# %%
multi_abc=inv.productmix(data['Description'],data['total_sales'],data['total_revenue'])

# %%
multi_abc.head(2)
# Out:
#                                     skus  sales    revenue  sales_mix  \
# 3769            REGENCY CAKESTAND 3 TIER  24139  277656.25   0.002293
# 5047  WHITE HANGING HEART T-LIGHT HOLDER  91757  247048.01   0.008715
#
#       comulative_sales  revenue_mix  comulative_revenue sales_category  \
# 3769          0.177816     0.015980            0.015980              A
# 5047          0.018705     0.014219            0.030199              A
#
#      revenue_category product_mix
# 3769                A         A_A
# 5047                A         A_A

# %%
multi_abc['product_mix'].value_counts().sort_values()
# Out:
# A_C      65
# C_A      74
# B_A     288
# A_B     317
# B_C     325
# C_B     413
# B_B     632
# A_A     775
# C_C    2394
# Name: product_mix, dtype: int64

# %%
multi_abc['product_mix'][multi_abc['revenue_category']=='A'].value_counts()
# Out:
# A_A    775
# B_A    288
# C_A     74
# Name: product_mix, dtype: int64

# %%
sns.countplot(x=multi_abc['product_mix'])
# Out:
# <Axes: xlabel='product_mix', ylabel='count'>

# %%
sns.barplot(x=multi_abc['product_mix'],y=multi_abc['sales'])
# Out:
# <Axes: xlabel='product_mix', ylabel='sales'>

# %%
retail=pd.read_csv('online_retail_udemy.csv')

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
retail.head(2)
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
#
#            InvoiceDate  Price  Customer ID         Country  Sales
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom   83.4
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom   81.0

# %%
retail['Sales']=retail['Quantity']*retail['Price']

# %%
retail.groupby('Country')['Sales'].describe()
# Out:
#                          count        mean         std        min      25%  \
# Country
# Australia               1913.0   87.364909  142.086762    -662.25  15.0000
# Austria                  938.0   24.709595   34.030870    -130.00  12.8250
# Bahrain                  126.0   22.710714   35.862325    -205.74  14.1750
# Belgium                 3123.0   20.356865   42.205593   -1508.65  13.2000
# Bermuda                   34.0   36.857059   53.406448      10.20  16.5000
# Brazil                    94.0   15.019894   24.370216       0.55   2.5125
# Canada                   228.0   21.416842   49.965088       2.50  11.5500
# Channel Islands         1664.0   24.912025   54.940967    -934.66  14.8500
# Cyprus                  1176.0   20.546548   31.775834    -320.69  10.2000
# Czech Republic            30.0   23.590667   26.302604     -35.76  15.6000
# Denmark                  817.0   80.466450  262.112354   -3630.80  15.0000
# EIRE                   17866.0   34.452007  106.460374   -2736.16  13.5000
# European Community        61.0   21.176230   11.514247      -8.50  15.0000
# Finland                 1049.0   28.135796   43.201619     -91.89  13.2000
# France                 14330.0   22.902428  103.079727   -8322.12  10.4000
# Germany                17624.0   23.717009   36.718110    -715.02  12.5000
# Greece                   663.0   28.650814   32.871839     -50.00  12.7500
# Hong Kong                364.0   38.569505  359.140040   -2653.95  15.0000
# Iceland                  253.0   22.266087   20.609093       5.04  13.2000
# Israel                   371.0   29.938598   38.433618    -136.00  12.5000
# Italy                   1534.0   19.999576   30.539063    -660.86  12.6000
# Japan                    582.0   75.217491  292.986889   -1591.20   1.6500
# Korea                     63.0   15.076508   19.365294     -19.80  10.3500
# Lebanon                   58.0   32.170862   28.710448     -39.67  15.3000
# Lithuania                189.0   34.675873   21.718351       3.36  16.5000
# Malta                    299.0   17.365284  169.982667   -1868.56  10.2000
# Netherlands             5140.0  106.716916  152.564837    -947.08  16.5000
# Nigeria                   32.0   -0.208125   20.033587     -79.05   1.2500
# Norway                  1455.0   26.971155  397.969720   -6958.17  14.8500
# Poland                   535.0   19.678673   16.010896     -46.80  12.7000
# Portugal                2620.0   20.281221   59.869255   -1241.98  10.2000
# RSA                      169.0   19.935089  158.194532   -1435.29  10.2000
# Saudi Arabia              10.0   13.117000   10.861336     -14.75  12.5850
# Singapore                346.0   38.029364  430.837460   -3949.32  16.6000
# Spain                   3811.0   24.103773   99.725162   -1715.85   9.9500
# Sweden                  1364.0   64.376408  113.184545   -1188.00  15.0000
# Switzerland             3189.0   31.272738   41.959312    -179.00  13.2000
# Thailand                  76.0   40.401842   68.994774       8.50  14.8500
# USA                      535.0   11.750542   25.810638     -74.88   2.0250
# United Arab Emirates     500.0   19.897300   39.624612    -503.90  10.2000
# United Kingdom        981330.0   16.694266  303.033401 -168469.60   3.3500
# Unspecified              756.0   12.813915   45.770770   -1189.94   5.0400
# West Indies               54.0    9.933519    9.122665       0.65   3.7875
#
#                          50%       75%        max
# Country
# Australia             30.000  108.0000    1718.40
# Austria               17.000   23.4000     360.00
# Bahrain               17.000   24.9500     205.74
# Belgium               16.600   20.8000    1508.65
# Bermuda               21.000   29.9250     241.92
# Brazil                 5.575   17.2550     175.20
# Canada                15.300   19.8000     550.94
# Channel Islands       17.400   25.5000     885.00
# Cyprus                15.300   20.2800     350.40
# Czech Republic        25.300   39.7800      70.80
# Denmark               25.920   60.0000    3630.80
# EIRE                  17.400   29.9000    2736.16
# European Community    17.700   24.9000      60.00
# Finland               17.400   25.2000     551.20
# France                16.500   23.4000    4161.06
# Germany               17.000   23.4000     876.00
# Greece                16.950   25.2000     229.50
# Hong Kong             23.400   51.3750    2653.95
# Iceland               17.000   23.4000     249.60
# Israel                19.550   31.8000     350.40
# Italy                 17.000   22.5000     300.00
# Japan                 25.920  100.8000    3794.40
# Korea                 17.700   20.2200     100.80
# Lebanon               19.800   39.8000     153.00
# Lithuania             30.000   46.8000     122.40
# Malta                 15.000   17.8800    1868.56
# Netherlands           69.600  145.0000    4992.00
# Nigeria                1.950    5.3125      27.82
# Norway                19.800   35.4000    6958.17
# Poland                17.400   20.8000     120.00
# Portugal              15.800   20.8000    1241.98
# RSA                   15.000   19.8000    1435.29
# Saudi Arabia          17.700   19.2750      19.80
# Singapore             30.000   51.0000    3949.32
# Spain                 15.000   20.2800    1350.00
# Sweden                22.500   86.6400    1188.00
# Switzerland           17.700   33.0000     850.00
# Thailand              15.600   21.7500     360.00
# USA                   13.200   19.8000     302.40
# United Arab Emirates  16.500   25.2000     503.90
# United Kingdom         8.470   16.9500  168469.60
# Unspecified           13.200   17.7000      91.80
# West Indies            7.530   14.3600      46.80

# %%
Sales_Country=retail.groupby(['Country','Description'])['Sales'].sum()
Sales_Country=pd.DataFrame(Sales_Country)
Sales_Country
# Out:
#                                                 Sales
# Country     Description
# Australia    DOLLY GIRL BEAKER                 216.00
#              I LOVE LONDON MINI BACKPACK        16.60
#             10 COLOUR SPACEBOY PEN              40.80
#             12 PENCIL SMALL TUBE WOODLAND      211.20
#             12 PENCILS SMALL TUBE RED SPOTTY    15.60
# ...                                               ...
# West Indies VINTAGE BEAD PINK SCARF             23.85
#             WHITE AND BLUE CERAMIC OIL BURNER    7.50
#             WOODLAND PARTY BAG + STICKER SET     1.65
#             WOVEN BERRIES CUSHION COVER          9.90
#             WOVEN FROST CUSHION COVER            9.90
#
# [30696 rows x 1 columns]

# %%
retail.groupby(['Description','Country'])['Sales'].agg(Sales=('Quantity',np.sum))
#retail.groupby(['Description','Country'])['Sales'].agg(Sales=('Sales', np.sum))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 retail.groupby(['Description','Country'])['Sales'].agg(Sales=('Quantity',np.sum))
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:271, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     269 columns = None
#     270 if relabeling:
# --> 271     columns, func = validate_func_kwargs(kwargs)
#     272     kwargs = {}
#     274 if isinstance(func, str):
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\apply.py:1598, in validate_func_kwargs(kwargs)
#    1596 for col_func in kwargs.values():
#    1597     if not (isinstance(col_func, str) or callable(col_func)):
# -> 1598         raise TypeError(tuple_given_message.format(type(col_func).__name__))
#    1599     func.append(col_func)
#    1600 if not columns:
#
# TypeError: func is expected but received tuple in **kwargs.

# %%
country_data=retail.groupby(['Description', 'Country']).agg(Quantity=('Quantity', 'sum'),Sales=('Sales','sum'))

# %%
country_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30696 entries, 0 to 30695
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Description  30696 non-null  object
#  1   Country      30696 non-null  object
#  2   Quantity     30696 non-null  int64
#  3   Sales        30696 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 959.4+ KB

# %%
country_data=country_data.reset_index()

# %%
country_data.loc[:'Description']
# Out:
#                                Description         Country  Quantity    Sales
# 0        DOORMAT UNION JACK GUNS AND ROSES           Malta         2    13.50
# 1        DOORMAT UNION JACK GUNS AND ROSES  United Kingdom       177  1193.31
# 2                 3 STRIPEY MICE FELTCRAFT         Germany        36    70.20
# 3                 3 STRIPEY MICE FELTCRAFT     Netherlands        19    37.05
# 4                 3 STRIPEY MICE FELTCRAFT        Portugal         6    11.70
# ...                                    ...             ...       ...      ...
# 30691          wrongly marked carton 22804  United Kingdom      -256     0.00
# 30692         wrongly marked. 23343 in box  United Kingdom     -3100     0.00
# 30693         wrongly sold (22719) barcode  United Kingdom       170     0.00
# 30694                 wrongly sold as sets  United Kingdom      -600     0.00
# 30695                    wrongly sold sets  United Kingdom      -975     0.00
#
# [30696 rows x 4 columns]

# %%
help(inv.productmix_storelevel)
# Out:
# Help on function productmix_storelevel in module inventorize3:
#
# productmix_storelevel(SKUs, sales, revenue, storeofsku)
#     [Identyfing ABC category based on the pareto rule for both demand and selling price,a mix of nine categories are produced.
#        Identyfing ABC category based on the pareto rule.A category is up to 80%. B category is up 95% and C category is up to 100%.
#        in this fuction the data is splitted by store and a product mix is made on each store individually.]
#
#     Args:
#       SKUs ([array]): [charachter, a vector of SKU names.]
#       sales ([array]): [a vector of items sold per sku, should be the same number of rows as SKUs.]
#       revenue ([array]): [a vector of total revenue  per sku, should be the same number of rows as SKUs.]
#       storeofsku ([array]): [vector, which store the SKU is sold at.should be the same number of rows as SKUs.]
#
#     Returns:
#       [pandas.DataFrame]: [a dataframe that contains ABC categories by store with a bar plot of the count of items in each category.]
#     Examples:
#       [ productmix_storelevel(SKUs= numpy.array(range(1,1001)),sales = ales= numpy.random.uniform(1,10000,1000),
#       revenue=numpy.random.uniform(1,80000,1000),storeofsku = storeofsku= numpy.array([1,2,3,4,5]).repeat(200)))]

# %%
country_group
# Out:
#                                      sku  sales  revenue storeofsku  \
# 19653                            POSTAGE     10   525.00      Malta
# 11009              GRAND CHOCOLATECANDLE    147   198.75      Malta
# 21388           REGENCY CAKESTAND 3 TIER     12   153.00      Malta
# 28247               VICTORIAN SEWING KIT    144   122.40      Malta
# 21513              REGENCY TEAPOT ROSES       8    79.60      Malta
# ...                                  ...    ...      ...        ...
# 1810   ASSORTED ICE CREAM FRIDGE MAGNETS     24    15.60    Bermuda
# 5530        CHILDS APRON SPACEBOY DESIGN      8    15.60    Bermuda
# 3089       BLUE FAIRY CAKE CHILD'S APRON      8    15.60    Bermuda
# 21027            RED SPOTTY CHILDS APRON      8    15.60    Bermuda
# 25283        SET/6 3D KIT CARDS FOR KIDS     12    10.20    Bermuda
#
#        sales_mix  comulative_sales  revenue_mix  comulative_revenue  \
# 19653   0.004014          0.708952     0.101113            0.101113
# 11009   0.059012          0.059012     0.038278            0.139391
# 21388   0.004817          0.680851     0.029467            0.168858
# 28247   0.057808          0.116821     0.023574            0.192432
# 21513   0.003212          0.719791     0.015331            0.207763
# ...          ...               ...          ...                 ...
# 1810    0.008578          0.903503     0.012449            0.954514
# 5530    0.002859          0.982130     0.012449            0.966963
# 3089    0.002859          0.984989     0.012449            0.979412
# 21027   0.002859          0.987848     0.012449            0.991860
# 25283   0.004289          0.930665     0.008140            1.000000
#
#       sales_category revenue_category product_mix
# 19653              A                A         A_A
# 11009              A                A         A_A
# 21388              A                A         A_A
# 28247              A                A         A_A
# 21513              A                A         A_A
# ...              ...              ...         ...
# 1810               B                C         B_C
# 5530               C                C         C_C
# 3089               C                C         C_C
# 21027              C                C         C_C
# 25283              B                C         B_C
#
# [30696 rows x 11 columns]

# %%
country_group=inv.productmix_storelevel(country_data['Description'],country_data['Quantity'],country_data['Sales'],country_data['Country'])

# %%
country_group[country_group['storeofsku']=='United Kingdom'].groupby('product_mix')['storeofsku'].count()  # multicriterion ABC for different stores/country
# Out:
# product_mix
# A_A     696
# A_B     249
# A_C      99
# B_A     220
# B_B     414
# B_C     359
# C_A      98
# C_B     410
# C_C    3123
# Name: storeofsku, dtype: int64

# %%
supplier=pd.read_csv('supplier_data.csv')

# %%
supplier   # 0 rating means as per the feature and 0.5 is not in favour of feature eg if product is available then its 0 if less available/risky then its 0.5
# Out:
#       supplier     product  availability  no_suppliers  standard  \
# 0    supplier1   product_1           0.0           0.3       0.0
# 1    supplier1   product_2           0.0           0.3       0.0
# 2    supplier1   product_3           0.0           0.3       0.0
# 3    supplier1   product_4           0.0           0.3       0.0
# 4    supplier1   product_5           0.0           0.6       0.0
# 5    supplier1   product_6           0.0           0.7       0.0
# 6    supplier2   product_7           0.5           0.0       0.3
# 7    supplier2   product_8           0.5           0.0       0.3
# 8    supplier2   product_9           0.5           0.0       0.3
# 9    supplier2  product_10           0.5           0.0       0.3
# 10   supplier2  product_11           0.5           0.0       0.3
# 11   supplier2  product_12           0.5           0.0       0.3
# 12   supplier3  product_13           0.5           0.0       0.0
# 13   supplier3  product_14           0.5           0.0       0.0
# 14   supplier3  product_15           0.5           0.0       0.0
# 15   supplier3  product_16           0.5           0.0       0.0
# 16   supplier3  product_17           0.4           0.0       0.0
# 17   supplier3  product_18           0.4           0.0       0.0
# 18  supplier 4  product_19           0.0           0.5       0.5
# 19  supplier 4  product_20           0.0           0.5       0.5
# 20  supplier 4  product_21           0.0           0.5       0.5
# 21  supplier 4  product_22           0.0           0.5       0.5
# 22  supplier 4  product_23           0.0           0.5       0.5
# 23  supplier 4  product_24           0.0           0.5       0.5
#
#     price_fluctuation  Quantity  price
# 0                 0.5       710    360
# 1                 0.5      2997   2740
# 2                 0.5      3917   2919
# 3                 0.5      3827   3246
# 4                 0.0      3882   3596
# 5                 0.0      3663    917
# 6                 0.0      3517   2639
# 7                 0.0       450   1384
# 8                 0.0      1438    842
# 9                 0.0      2887    323
# 10                0.0       764   1923
# 11                0.0       336   1071
# 12                0.0      2084   2795
# 13                0.0      3379   1794
# 14                0.0       833    941
# 15                0.0       238   2858
# 16                0.5      2970   2774
# 17                0.5      3618   3867
# 18                0.5      1533    667
# 19                0.5      2766   2799
# 20                0.0      2706   3735
# 21                0.0      3094    861
# 22                0.0       508   1579
# 23                0.0      1586     75

# %%
supplier.columns
# Out:
# Index(['supplier', 'product', 'availability', 'no_suppliers', 'standard',
#        'price_fluctuation', 'Quantity', 'price'],
#       dtype='object')

# %%
supplier['risk index']=supplier['availability']+supplier['no_suppliers']+supplier['standard']+supplier['price_fluctuation']

# %%
supplier['Value']=supplier['Quantity']*supplier['price']

# %%
supplier.head()
# Out:
#     supplier    product  availability  no_suppliers  standard  \
# 0  supplier1  product_1           0.0           0.3       0.0
# 1  supplier1  product_2           0.0           0.3       0.0
# 2  supplier1  product_3           0.0           0.3       0.0
# 3  supplier1  product_4           0.0           0.3       0.0
# 4  supplier1  product_5           0.0           0.6       0.0
#
#    price_fluctuation  Quantity  price  risk index     Value
# 0                0.5       710    360         0.8    255600
# 1                0.5      2997   2740         0.8   8211780
# 2                0.5      3917   2919         0.8  11433723
# 3                0.5      3827   3246         0.8  12422442
# 4                0.0      3882   3596         0.6  13959672

# %%
supplier.describe()
# Out:
#        availability  no_suppliers   standard  price_fluctuation     Quantity  \
# count     24.000000     24.000000  24.000000          24.000000    24.000000
# mean       0.241667      0.229167   0.200000           0.166667  2237.625000
# std        0.248328      0.251049   0.216695           0.240772  1311.452391
# min        0.000000      0.000000   0.000000           0.000000   238.000000
# 25%        0.000000      0.000000   0.000000           0.000000   815.750000
# 50%        0.200000      0.150000   0.150000           0.000000  2736.000000
# 75%        0.500000      0.500000   0.350000           0.500000  3413.500000
# max        0.500000      0.700000   0.500000           0.500000  3917.000000
#
#              price  risk index         Value
# count    24.000000   24.000000  2.400000e+01
# mean   1946.041667    0.837500  5.064812e+06
# std    1185.365821    0.258444  4.847504e+06
# min      75.000000    0.500000  1.189500e+05
# 25%     903.000000    0.775000  7.975622e+05
# 50%    1858.500000    0.800000  3.011452e+06
# 75%    2813.750000    0.925000  8.499426e+06
# max    3867.000000    1.500000  1.399081e+07

# %%
3.011452e+06
# Out:
# 3011452.0

# %%
def supplier_matrix(x,y):
    if ((x>=4000000) & (y>=1)):
        return 'Strategic'
    elif((x>=4000000) & (y<1)):
        return 'Leverage'
    elif((x<4000000) & (y<1)):
        return 'Non-Critical'
    elif((x<4000000) & (y>=1)):
        return 'Bottel Neck'

# %%
supplier_matrix(240000,2)
# Out:
# 'Bottel Neck'

# %%
#supplier['Category']=supplier[['Value','risk index']].apply(supplier_matrix)
supplier['Category']=supplier.apply(lambda x: supplier_matrix(x['Value'], x['risk index']),axis=1)

# %%
supplier.head()
# Out:
#     supplier    product  availability  no_suppliers  standard  \
# 0  supplier1  product_1           0.0           0.3       0.0
# 1  supplier1  product_2           0.0           0.3       0.0
# 2  supplier1  product_3           0.0           0.3       0.0
# 3  supplier1  product_4           0.0           0.3       0.0
# 4  supplier1  product_5           0.0           0.6       0.0
#
#    price_fluctuation  Quantity  price  risk index     Value      Category
# 0                0.5       710    360         0.8    255600  Non-Critical
# 1                0.5      2997   2740         0.8   8211780      Leverage
# 2                0.5      3917   2919         0.8  11433723      Leverage
# 3                0.5      3827   3246         0.8  12422442      Leverage
# 4                0.0      3882   3596         0.6  13959672      Leverage

# %%
supplier['Category'].value_counts()
# Out:
# Leverage        10
# Non-Critical     8
# Bottel Neck      4
# Strategic        2
# Name: Category, dtype: int64

# %%
supplier[supplier['Category']=='Leverage']
# Out:
#      supplier     product  availability  no_suppliers  standard  \
# 1   supplier1   product_2           0.0           0.3       0.0
# 2   supplier1   product_3           0.0           0.3       0.0
# 3   supplier1   product_4           0.0           0.3       0.0
# 4   supplier1   product_5           0.0           0.6       0.0
# 5   supplier1   product_6           0.0           0.7       0.0
# 6   supplier2   product_7           0.5           0.0       0.3
# 12  supplier3  product_13           0.5           0.0       0.0
# 13  supplier3  product_14           0.5           0.0       0.0
# 16  supplier3  product_17           0.4           0.0       0.0
# 17  supplier3  product_18           0.4           0.0       0.0
#
#     price_fluctuation  Quantity  price  risk index     Value  Category
# 1                 0.5      2997   2740         0.8   8211780  Leverage
# 2                 0.5      3917   2919         0.8  11433723  Leverage
# 3                 0.5      3827   3246         0.8  12422442  Leverage
# 4                 0.0      3882   3596         0.6  13959672  Leverage
# 5                 0.0      3663    917         0.7   3358971  Leverage
# 6                 0.0      3517   2639         0.8   9281363  Leverage
# 12                0.0      2084   2795         0.5   5824780  Leverage
# 13                0.0      3379   1794         0.5   6061926  Leverage
# 16                0.5      2970   2774         0.9   8238780  Leverage
# 17                0.5      3618   3867         0.9  13990806  Leverage

# %%
sns.scatterplot(x='risk index',y='Value',data=supplier,hue='Category')
plt.axvline(x=1,linestyle='dotted', color='black')
plt.axhline(y=6000000, linestyle='dotted', color='black')
plt.plot()
# Out:
# []
